# %% [markdown]
# # Image clasification with multilayer perceptron fashion mnist
# <img src="dataset.png">

# %%
import tensorflow as tf
import numpy as np
import datetime
from tensorflow.keras.datasets import fashion_mnist
import matplotlib.pyplot as plt

# %% [markdown]
# ##  Load data base

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
plt.imshow(x_train[5])

# %%
# Images normalizer
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Images normalizer
x_train = x_train / 255.0
x_test = x_test / 255.0 

# Reshape vector images for MLP One dimensional
x_train = x_train.reshape(-1, 28*28)
x_test = x_test.reshape(-1, 28*28)

# %% [markdown]
# ## Criate model arquiteture

# %%
class Network():
    def __init__(self, input_shape, number_class ):
        self.model = tf.keras.models.Sequential()
        self.input_shape = input_shape
        self.number_class = number_class
    
    def net(self):
        self.model.add(tf.keras.layers.Dense(units = 128, activation = 'relu', input_shape=(self.input_shape)))
        self.model.add(tf.keras.layers.Dropout(0.2))
        self.model.add(tf.keras.layers.Dense(units=128, activation='relu'))
        self.model.add(tf.keras.layers.Dropout(0.2))
        self.model.add(tf.keras.layers.Dense(units=128, activation='relu'))
        self.model.add(tf.keras.layers.Dropout(0.2))
        self.model.add(tf.keras.layers.Dense(units=128, activation='relu'))
        self.model.add(tf.keras.layers.Dense(units = self.number_class, activation = 'softmax'))
        self.model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = ['sparse_categorical_accuracy'])
        return self.model

# %% [markdown]
# ## Instantiating the Neural Network

# %%
input_shape = (784, )
number_class = 10
obj_net = Network(input_shape, number_class)
network = obj_net.net()
network.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 151,306
# Trainable params: 151,306
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training the  neural Network

# %%
network.fit(x_train, y_train, epochs =30)
# Out:
# Train on 60000 samples
# Epoch 1/30
# 60000/60000 [==============================] - 9s 157us/sample - loss: 0.8671 - sparse_categorical_accuracy: 0.6647
# Epoch 2/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.5769 - sparse_categorical_accuracy: 0.7850
# Epoch 3/30
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.5022 - sparse_categorical_accuracy: 0.8195
# Epoch 4/30
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.4658 - sparse_categorical_accuracy: 0.8319
# Epoch 5/30
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.4382 - sparse_categorical_accuracy: 0.8412
# Epoch 6/30
# 60000/60000 [==============================] - 8s 141us/sample - loss: 0.4154 - sparse_categorical_accuracy: 0.8504
# Epoch 7/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.4041 - sparse_categorical_accuracy: 0.8535
# Epoch 8/30
# 60000/60000 [==============================] - 8s 135us/sample - loss: 0.3924 - sparse_categorical_accuracy: 0.8573
# Epoch 9/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3843 - sparse_categorical_accuracy: 0.8595
# Epoch 10/30
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.3734 - sparse_categorical_accuracy: 0.8645
# Epoch 11/30
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.3672 - sparse_categorical_accuracy: 0.8660
# Epoch 12/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3626 - sparse_categorical_accuracy: 0.8684
# Epoch 13/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3572 - sparse_categorical_accuracy: 0.8704
# Epoch 14/30
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.3508 - sparse_categorical_accuracy: 0.8726
# Epoch 15/30
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.3441 - sparse_categorical_accuracy: 0.8748
# Epoch 16/30
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.3424 - sparse_categorical_accuracy: 0.8748
# Epoch 17/30
# 60000/60000 [==============================] - 9s 142us/sample - loss: 0.3390 - sparse_categorical_accuracy: 0.8761
# Epoch 18/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3366 - sparse_categorical_accuracy: 0.8773
# Epoch 19/30
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.3302 - sparse_categorical_accuracy: 0.8783
# Epoch 20/30
# 60000/60000 [==============================] - 8s 135us/sample - loss: 0.3291 - sparse_categorical_accuracy: 0.8794
# Epoch 21/30
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.3232 - sparse_categorical_accuracy: 0.8819
# Epoch 22/30
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.3206 - sparse_categorical_accuracy: 0.8820
# Epoch 23/30
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.3194 - sparse_categorical_accuracy: 0.8834
# Epoch 24/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3172 - sparse_categorical_accuracy: 0.8832
# Epoch 25/30
# 60000/60000 [==============================] - 8s 137us/sample - loss: 0.3146 - sparse_categorical_accuracy: 0.8847
# Epoch 26/30
# 60000/60000 [==============================] - 8s 136us/sample - loss: 0.3113 - sparse_categorical_accuracy: 0.8853
# Epoch 27/30
# 60000/60000 [==============================] - 8s 138us/sample - loss: 0.3083 - sparse_categorical_accuracy: 0.8868
# Epoch 28/30
# 60000/60000 [==============================] - 8s 140us/sample - loss: 0.3072 - sparse_categorical_accuracy: 0.8877
# Epoch 29/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3054 - sparse_categorical_accuracy: 0.8882
# Epoch 30/30
# 60000/60000 [==============================] - 8s 139us/sample - loss: 0.3014 - sparse_categorical_accuracy: 0.8899

# %% [markdown]
# ## Test model data base test

# %%
test_loss, test_accuracy = network.evaluate(x_test, y_test)
# Out:
# ================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================ ...

# %% [markdown]
# ## Save model

# %%
model_json = network.to_json()
with open("fashion_model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# ## Save weights

# %%
network.save_weights("fashion_model.h5")
